# %% [markdown]
# ## Customer Segmentation for Cannondale bikes
#
# - k-means clustering will be used to segment customers into distinct groups based on purchasing habits.
# - The k-means clustering algorithm works by finding like groups based on Euclidean distance, a measure of distance or similarity. The practitioner selects k groups to cluster, and the algorithm finds the best centroids for the k groups.
# - Those groups can be used to determine which factors group members relate. For customers, these would be their buying preferences.
# - Datasets: Cannondale bikes data set

# %% [markdown]
# ### Step1: Data preprocessing

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc

# %matplotlib inline
plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'

import operator
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')

# %%
customers = pd.read_excel("bikeshops.xlsx")
products = pd.read_excel("bikes.xlsx")
orders = pd.read_excel("orders.xlsx")
print('=' *50)
print("Shape of orders:" + str(orders.shape))
display(orders.head(3))
print('=' *50)
print("Shape of customers:" + str(customers.shape))
display(customers.head(3))
print('=' *50)
print("Shape of products:" + str(products.shape))
display(products.head(3))
# Out:
# ==================================================
# Shape of orders:(15644, 7)
#    Unnamed: 0  order.id  order.line order.date  customer.id  product.id  \
# 0           1         1           1 2011-01-07            2          48
# 1           2         1           2 2011-01-07            2          52
# 2           3         2           1 2011-01-10           10          76
#
#    quantity
# 0         1
# 1         1
# 2         1
# ==================================================
# Shape of customers:(30, 6)
#    bikeshop.id                 bikeshop.name bikeshop.city bikeshop.state  \
# 0            1  Pittsburgh Mountain Machines    Pittsburgh             PA
# 1            2      Ithaca Mountain Climbers        Ithaca             NY
# 2            3       Columbus Race Equipment      Columbus             OH
#
#     latitude  longitude
# 0  40.440625 -79.995886
# 1  42.443961 -76.501881
# 2  39.961176 -82.998794
# ==================================================
# Shape of products:(97, 6)
#    bike.id                           model category1   category2   frame  \
# 0        1         Supersix Evo Black Inc.      Road  Elite Road  Carbon
# 1        2        Supersix Evo Hi-Mod Team      Road  Elite Road  Carbon
# 2        3  Supersix Evo Hi-Mod Dura Ace 1      Road  Elite Road  Carbon
#
#    price
# 0  12790
# 1  10660
# 2   7990

# %% [markdown]
#      Q: Next, convert the unit price to categorical high/low variables. To do this, you can divide the unit prices into two halves using the median as the split point.

# %%
price_median = products['price'].median()
print('=' *50)
print("The median of the price is:" + str(price_median))
products['price'] = products['price'].apply(lambda x: 'High' if x >= price_median else 'Low' )
# Out:
# ==================================================
# The median of the price is:3200.0

# %% [markdown]
#     Q: Then, you will load all three dataset (products, orders, and customers) and merge them together into one single data frame for further analysis. Remember, you can link the three datasets together by using the product.id and customer.id in the orders table.

# %%
orders_extended0 = orders.merge(products, how='inner', left_on= 'product.id', right_on='bike.id').merge(customers, how ='inner',left_on = 'customer.id', right_on = 'bikeshop.id')
orders_extended = orders_extended0.copy()
print('=' *50)
print(orders_extended.shape)
orders_extended.head()
# Out:
# ==================================================
# (15644, 19)
#    Unnamed: 0  order.id  order.line order.date  customer.id  product.id  \
# 0           1         1           1 2011-01-07            2          48
# 1        1002       132           6 2011-05-13            2          48
# 2        3831       507           2 2012-06-26            2          48
# 3        3991       528          18 2012-07-16            2          48
# 4        5359       691          13 2013-02-05            2          48
#
#    quantity  bike.id            model category1      category2   frame price  \
# 0         1       48  Jekyll Carbon 2  Mountain  Over Mountain  Carbon  High
# 1         1       48  Jekyll Carbon 2  Mountain  Over Mountain  Carbon  High
# 2         1       48  Jekyll Carbon 2  Mountain  Over Mountain  Carbon  High
# 3         1       48  Jekyll Carbon 2  Mountain  Over Mountain  Carbon  High
# 4         1       48  Jekyll Carbon 2  Mountain  Over Mountain  Carbon  High
#
#    bikeshop.id             bikeshop.name bikeshop.city bikeshop.state  \
# 0            2  Ithaca Mountain Climbers        Ithaca             NY
# 1            2  Ithaca Mountain Climbers        Ithaca             NY
# 2            2  Ithaca Mountain Climbers        Ithaca             NY
# 3            2  Ithaca Mountain Climbers        Ithaca             NY
# 4            2  Ithaca Mountain Climbers        Ithaca             NY
#
#     latitude  longitude
# 0  42.443961 -76.501881
# 1  42.443961 -76.501881
# 2  42.443961 -76.501881
# 3  42.443961 -76.501881
# 4  42.443961 -76.501881

# %% [markdown]
#     Q: Spread the customers by quantity of bike models purchased. To do this, you can group the data by model & model features (bikeshop.name', 'model', 'category1', 'category2', 'frame', 'price') and summarize by quantity purchased. Then, you can use a pivot table to allocate the aggregated quantitties across different bikeshops.

# %%
customer_trend = pd.pivot_table(orders_extended,index=['model', 'category1', 'category2', 'frame', 'price'],
               values=['order.id'],
               aggfunc='count',fill_value=0,
               columns=["bikeshop.name"]
                      )
customer_trend.columns = customer_trend.columns.levels[1]
print('=' *50)
print(customer_trend.shape)
customer_trend.head()
# Out:
# ==================================================
# (97, 30)
# bikeshop.name                                           Albuquerque Cycles  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                    3
# Bad Habit 2         Mountain  Trail     Aluminum Low                     2
# Beast of the East 1 Mountain  Trail     Aluminum Low                     3
# Beast of the East 2 Mountain  Trail     Aluminum Low                     2
# Beast of the East 3 Mountain  Trail     Aluminum Low                     1
#
# bikeshop.name                                           Ann Arbor Speed  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                 4
# Bad Habit 2         Mountain  Trail     Aluminum Low                  6
# Beast of the East 1 Mountain  Trail     Aluminum Low                  7
# Beast of the East 2 Mountain  Trail     Aluminum Low                  5
# Beast of the East 3 Mountain  Trail     Aluminum Low                  2
#
# bikeshop.name                                           Austin Cruisers  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                 1
# Bad Habit 2         Mountain  Trail     Aluminum Low                  1
# Beast of the East 1 Mountain  Trail     Aluminum Low                  2
# Beast of the East 2 Mountain  Trail     Aluminum Low                  2
# Beast of the East 3 Mountain  Trail     Aluminum Low                  0
#
# bikeshop.name                                           Cincinnati Speed  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                  2
# Bad Habit 2         Mountain  Trail     Aluminum Low                   0
# Beast of the East 1 Mountain  Trail     Aluminum Low                   0
# Beast of the East 2 Mountain  Trail     Aluminum Low                   0
# Beast of the East 3 Mountain  Trail     Aluminum Low                   0
#
# bikeshop.name                                           Columbus Race Equipment  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                         4
# Bad Habit 2         Mountain  Trail     Aluminum Low                          0
# Beast of the East 1 Mountain  Trail     Aluminum Low                          0
# Beast of the East 2 Mountain  Trail     Aluminum Low                          1
# Beast of the East 3 Mountain  Trail     Aluminum Low                          1
#
# bikeshop.name                                           Dallas Cycles  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum
\
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                    5
# Bad Habit 2         Mountain  Trail     Aluminum Low                    11
# Beast of the East 1 Mountain  Trail     Aluminum Low                     5
# Beast of the East 2 Mountain  Trail     Aluminum Low                     8
# Beast of the East 3 Mountain  Trail     Aluminum Low                     4
#
# bikeshop.name                                           San Antonio Bike Shop  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                       3
# Bad Habit 2         Mountain  Trail     Aluminum Low                        0
# Beast of the East 1 Mountain  Trail     Aluminum Low                        1
# Beast of the East 2 Mountain  Trail     Aluminum Low                        2
# Beast of the East 3 Mountain  Trail     Aluminum Low                        3
#
# bikeshop.name                                           San Francisco Cruisers  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                        1
# Bad Habit 2         Mountain  Trail     Aluminum Low                         1
# Beast of the East 1 Mountain  Trail     Aluminum Low                         0
# Beast of the East 2 Mountain  Trail     Aluminum Low                         1
# Beast of the East 3 Mountain  Trail     Aluminum Low                         0
#
# bikeshop.name                                           Seattle Race Equipment  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High                        2
# Bad Habit 2         Mountain  Trail     Aluminum Low                         1
# Beast of the East 1 Mountain  Trail     Aluminum Low                         2
# Beast of the East 2 Mountain  Trail     Aluminum Low                         3
# Beast of the East 3 Mountain  Trail     Aluminum Low                         1
#
# bikeshop.name                                           Tampa 29ers  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High             4
# Bad Habit 2         Mountain  Trail     Aluminum Low              0
# Beast of the East 1 Mountain  Trail     Aluminum Low              2
# Beast of the East 2 Mountain  Trail     Aluminum Low              3
# Beast of the East 3 Mountain  Trail     Aluminum Low              2
#
# bikeshop.name                                           Wichita Speed
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High               3
# Bad Habit 2         Mountain  Trail     Aluminum Low                0
# Beast of the East 1 Mountain  Trail     Aluminum Low                0
# Beast of the East 2 Mountain  Trail     Aluminum Low                1
# Beast of the East 3 Mountain  Trail     Aluminum Low                0
#
# [5 rows x 30 columns]

# %% [markdown]
#        Q: Last, we need to scale (normalize) the quantity data. Unadjusted quantities presents a problem to the k-means algorithm. Some customers are larger than others meaning they purchase higher volumes. Fortunately, we can resolve this issue by converting the customer order quantities to proportion of the total bikes purchased by a customer.

# %%
# column-wise pct
for column in customer_trend.columns:
    customer_trend[column] = customer_trend[column].transform(lambda x: x/x.sum(axis = 0))
    
customer_trend.head()
# Out:
# bikeshop.name                                           Albuquerque Cycles  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High             0.014493
# Bad Habit 2         Mountain  Trail     Aluminum Low              0.009662
# Beast of the East 1 Mountain  Trail     Aluminum Low              0.014493
# Beast of the East 2 Mountain  Trail     Aluminum Low              0.009662
# Beast of the East 3 Mountain  Trail     Aluminum Low              0.004831
#
# bikeshop.name                                           Ann Arbor Speed  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum High          0.008677
# Bad Habit 2         Mountain  Trail     Aluminum Low           0.013015
# Beast of the East 1 Mountain  Trail     Aluminum Low           0.015184
# Beast of the East 2 Mountain  Trail     Aluminum Low           0.010846
# Beast of the East 3 Mountain  Trail     Aluminum Low           0.004338
#
# bikeshop.name                                           Austin Cruisers  \
# model               category1 category2 frame    price
# Bad Habit 1         Mountain  Trail     Aluminum
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Step 2: Perform k-Means Clustering
#     Q: Clearly state your choice of the parameter k and your assumption behind choosing a specific k parameter. How many clusters do you think there should be and why?
#
# - k-means package from the scikit-learn library is used.
# - The cluster range I choose is from **4 to 8**.
# - The underlying assumption is the customer base are most likely to be at least 4 groups; out of features category 1, 2, frame and price, mountain bike vs. road bike and premium vs affordable preferences are the most important factors.
# - Max number of clusters is limited to 8 to avoid overfitting the segments.

# %%
# The data frame is transposed to have the customers as rows and models as columns.
customer_trend1 = customer_trend.copy()
X = customer_trend1.T
print(X.shape)
X.head()
# Out:
# (30, 97)
# model                   Bad Habit 1 Bad Habit 2 Beast of the East 1  \
# category1                  Mountain    Mountain            Mountain
# category2                     Trail       Trail               Trail
# frame                      Aluminum    Aluminum            Aluminum
# price                          High         Low                 Low
# bikeshop.name
# Albuquerque Cycles         0.014493    0.009662            0.014493
# Ann Arbor Speed            0.008677    0.013015            0.015184
# Austin Cruisers            0.005208    0.005208            0.010417
# Cincinnati Speed           0.006711    0.000000            0.000000
# Columbus Race Equipment    0.013514    0.000000            0.000000
#
# model                   Beast of the East 2 Beast of the East 3  \
# category1                          Mountain            Mountain
# category2                             Trail               Trail
# frame                              Aluminum            Aluminum
# price                                   Low                 Low
# bikeshop.name
# Albuquerque Cycles                 0.009662            0.004831
# Ann Arbor Speed                    0.010846            0.004338
# Austin Cruisers                    0.010417            0.000000
# Cincinnati Speed                   0.000000            0.000000
# Columbus Race Equipment            0.003378            0.003378
#
# model                   CAAD Disc Ultegra CAAD12 105 CAAD12 Black Inc  \
# category1                            Road       Road             Road
# category2                      Elite Road Elite Road       Elite Road
# frame                            Aluminum   Aluminum         Aluminum
# price                                 Low        Low             High
# bikeshop.name
# Albuquerque Cycles               0.014493   0.009662         0.000000
# Ann Arbor Speed                  0.013015   0.013015         0.010846
# Austin Cruisers                  0.026042   0.020833         0.005208
# Cincinnati Speed                 0.016779   0.013423         0.020134
# Columbus Race Equipment          0.013514   0.020270         0.023649
#
# model                   CAAD12 Disc 105 CAAD12 Disc Dura Ace  ...  \
# category1                          Road                 Road  ...
# category2                    Elite Road           Elite Road  ...
# frame                          Aluminum             Aluminum  ...
# price                               Low                 High  ...
# bikeshop.name                                                 ...
# Albuquerque Cycles             0.019324             0.019324  ...
# Ann Arbor Speed                0.008677             0.010846  ...
# Austin Cruisers                0.020833             0.010417  ...
# Cincinnati Speed               0.010067             0.016779  ...
# Columbus Race Equipment        0.010135             0.016892  ...
#
# model                     Synapse Sora   Trail 1   Trail 2   Trail 3  \
# category1                         Road  Mountain  Mountain  Mountain
# category2               Endurance Road     Sport     Sport     Sport
# frame                         Aluminum  Aluminum  Aluminum  Aluminum
# price                              Low       Low       Low       Low
# bikeshop.name
# Albuquerque Cycles            0.000000  0.000000  0.004831  0.009662
# Ann Arbor Speed               0.006508  0.010846  0.015184  0.010846
# Austin Cruisers               0.020833  0.015625  0.020833  0.010417
# Cincinnati Speed              0.013423  0.000000  0.003356  0.003356
# Columbus Race Equipment       0.013514  0.003378  0.003378  0.006757
#
# model                     Trail 4   Trail 5 Trigger Carbon 1 Trigger Carbon 2  \
# category1                Mountain  Mountain         Mountain         Mountain
# category2                   Sport     Sport    Over Mountain    Over Mountain
# frame                    Aluminum  Aluminum           Carbon           Carbon
# price                         Low       Low             High             High
# bikeshop.name
# Albuquerque Cycles       0.024155  0.009662         0.009662         0.004831
# Ann Arbor Speed          0.004338  0.010846         0.000000         0.000000
# Austin Cruisers          0.010417  0.010417         0.000000         0.000000
# Cincinnati Speed         0.003356  0.000000         0.013423         0.006711
# Columbus Race Equipment  0.000000  0.000000         0.013514         0.006757
#
# model                   Trigger Carbon 3 Trigger Carbon 4
# category1                       Mountain         Mountain
# category2                  Over Mountain    Over Mountain
# frame                             Carbon           Carbon
# price                               High             High
# bikeshop.name
# Albuquerque Cycles              0.009662         0.009662
# Ann Arbor Speed                 0.000000         0.008677
# Austin Cruisers                 0.000000         0.020833
# Cincinnati Speed                0.013423         0.013423
# Columbus Race Equipment         0.016892         0.006757
#
# [5 rows x 97 columns]

# %% [markdown]
# #### Silhouette Score
# - Silhouette is a technique in clustering that validates the best cluster groups.
# - The best cluster is the one with the largest silhouette average width, which turns out to be **4** clusters.

# %%
#  Silhouette is a technique in clustering that validates the best cluster groups. 
score = []
K = range(4,9)
for k in K:
    kmeans = KMeans(n_clusters = k, random_state=50)
    kmeans.fit(X)
    labels = kmeans.labels_
    score.append(silhouette_score(X, labels))
plt.plot(K, score,'bx-')
plt.xlabel('Number of Cluster Centers')
plt.ylabel('Average silhouette_score')
plt.title('Silhouette score as Cluster Center Varies')
plt.show()

# %% [markdown]
# ### Step 3: Analyze the result
#     Q Inspect the groups find out which customers are grouped together.
#     Q Print out customer names that are in each segment.

# %%
best_k = 4
kmeans = KMeans(n_clusters=best_k, random_state=50).fit(X)
label = kmeans.labels_

cluster_map = pd.DataFrame()
cluster_map['customer'] = X.index
cluster_map['cluster'] = kmeans.labels_

for i in range(best_k):
    print("="*15 + "Cluster " + str(i) + "="*15)
    print(cluster_map[cluster_map["cluster"] == i]["customer"])
    print()
# Out:
# ===============Cluster 0===============
# 1                  Ann Arbor Speed
# 2                  Austin Cruisers
# 8         Indianapolis Velocipedes
# 14            Miami Race Equipment
# 16              Nashville Cruisers
# 17         New Orleans Velocipedes
# 19    Oklahoma City Race Equipment
# 27          Seattle Race Equipment
# Name: customer, dtype: object
#
# ===============Cluster 1===============
# 0         Albuquerque Cycles
# 5              Dallas Cycles
# 6           Denver Bike Shop
# 7             Detroit Cycles
# 10         Kansas City 29ers
# 12        Los Angeles Cycles
# 15     Minneapolis Bike Shop
# 18           New York Cycles
# 20    Philadelphia Bike Shop
# 21           Phoenix Bi-peds
# 23          Portland Bi-peds
# 24        Providence Bi-peds
# 25     San Antonio Bike Shop
# Name: customer, dtype: object
#
# ===============Cluster 2===============
# 3              Cincinnati Speed
# 4       Columbus Race Equipment
# 11             Las Vegas Cycles
# 13    Louisville Race Equipment
# 26       San Francisco Cruisers
# 29                Wichita Speed
# Name: customer, dtype: object
#
# ===============Cluster 3===============
# 9         Ithaca Mountain Climbers
# 22    Pittsburgh Mountain Machines
# 28                     Tampa 29ers
# Name: customer, dtype: object

# %% [markdown]
#     Q Determine the preferences of the customer segments by inspecting factors related to the model (e.g. price point, category of bike, etc.)
#     Q Then for each cluster, arrange top 10 bike models by cluster in descending order for the combination cluster centroids with bike models with feature inspection and print out this information.
#
# According to the assumption: mountain bike vs. road bike and premium vs affordable preferences.
#
# **cluster0: affordable + road**
# - The top 10 models purchased all but three has a affordable (low-price) and all has a road category. 6 out 10 have an Aluminum frame.
#
# **cluster1: affordable + mountain**
# - The top 10 models purchased all but two has a affordable (low-price) and all but three has mountain category. The all but three models has an Aluminum frame.
#
# **cluster2: premium + road**
# - The top 10 models purchased are predominantly high-price and road. The all but two models has a carbon frame.
#
# **cluster3: premium + mountain**
# - The top 10 models purchased are predominantly high-price and mountain. The all but one model has a carbon frame.

# %%
index = pd.MultiIndex.from_tuples(X.T.index, names=['model', 'category1', 'category2', 'frame', 'price'])
Preferenaces = pd.DataFrame(index= index)
Preferenaces = Preferenaces.reset_index()
lst = []
X1 = []
for i in range(best_k):
    idx = sorted(enumerate(kmeans.cluster_centers_[i]), key=operator.itemgetter(1),reverse = True)[:10]
    lst.append([idx[i][0] for i in range(len(idx))])
    X1.append([idx[i][1] for i in range(len(idx))])
    

for i in range(best_k):
    name = 'cluster' + str(i)
    print("="*20 + name + "="*20)

    name = Preferenaces.iloc[lst[i]]
    name['X1'] = X1[i]
    display(name)
# Out:
# ====================cluster0====================
#                       model category1       category2     frame price  \
# 80         Synapse Disc 105      Road  Endurance Road  Aluminum   Low
# 87             Synapse Sora      Road  Endurance Road  Aluminum   Low
# 82      Synapse Disc Tiagra      Road  Endurance Road  Aluminum   Low
# 10               CAAD12 Red      Road      Elite Road  Aluminum  High
# 70   Supersix Evo Ultegra 3      Road      Elite Road    Carbon  High
# 11           CAAD12 Ultegra      Road      Elite Road  Aluminum   Low
# 61           SuperX Ultegra      Road      Cyclocross    Carbon   Low
# 15             CAAD8 Tiagra      Road      Elite Road  Aluminum   Low
# 57        Slice Ultegra D12      Road      Triathalon    Carbon  High
# 74  Synapse Carbon Disc 105      Road  Endurance Road    Carbon   Low
#
#           X1
# 80  0.022197
# 87  0.022186
# 82  0.022163
# 10  0.020347
# 70  0.020335
# 11  0.020170
# 61  0.019623
# 15  0.019331
# 57  0.019198
# 74  0.019167
# ====================cluster1====================
#                       model category1           category2     frame price  \
# 8           CAAD12 Disc 105      Road          Elite Road  Aluminum   Low
# 21                   F-Si 2  Mountain  Cross Country Race  Aluminum   Low
# 25            F-Si Carbon 4  Mountain  Cross Country Race    Carbon   Low
# 92                  Trail 5  Mountain               Sport  Aluminum   Low
# 74  Synapse Carbon Disc 105      Road      Endurance Road    Carbon   Low
# 96         Trigger Carbon 4  Mountain       Over Mountain    Carbon  High
# 17               Catalyst 2  Mountain               Sport  Aluminum   Low
# 6                CAAD12 105      Road          Elite Road  Aluminum   Low
# 42             Scalpel 29 4  Mountain  Cross Country Race  Aluminum  High
# 30                  Habit 4  Mountain               Trail  Aluminum   Low
#
#           X1
# 8   0.017475
# 21  0.017290
# 25  0.017116
# 92  0.016579
# 74  0.016347
# 96  0.015748
# 17  0.015255
# 6   0.015160
# 42  0.015112
# 30  0.014998
# ====================cluster2====================
#                              model category1       category2     frame price  \
# 55       Slice Hi-Mod Dura Ace D12      Road      Triathalon    Carbon  High
# 10                      CAAD12 Red      Road      Elite Road  Aluminum  High
# 7                 CAAD12 Black Inc      Road      Elite Road  Aluminum  High
# 54         Slice Hi-Mod Black Inc.      Road      Triathalon    Carbon  High
# 64  Supersix Evo Hi-Mod Dura Ace 1      Road      Elite Road    Carbon  High
# 86         Synapse Hi-Mod Dura Ace      Road  Endurance Road    Carbon  High
# 84         Synapse Hi-Mod Disc Red      Road  Endurance Road    Carbon  High
# 63         Supersix Evo Black Inc.      Road      Elite Road    Carbon  High
# 70          Supersix Evo Ultegra 3      Road      Elite Road    Carbon  High
# 83  Synapse Hi-Mod Disc Black Inc.      Road  Endurance Road    Carbon  High
#
#           X1
# 55  0.022944
# 10  0.022335
# 7   0.021382
# 54  0.021208
# 64  0.020968
# 86  0.020955
# 84  0.020750
# 63  0.020434
# 70  0.019964
# 83  0.019664
# ====================cluster3====================
#                      model category1           category2     frame price  \
# 45  Scalpel 29 Carbon Race  Mountain  Cross Country Race    Carbon  High
# 34          Habit Carbon 2  Mountain               Trail    Carbon  High
# 49     Scalpel-Si Carbon 3  Mountain  Cross Country Race    Carbon  High
# 39         Jekyll Carbon 2  Mountain       Over Mountain    Carbon  High
# 95        Trigger Carbon 3  Mountain       Over Mountain    Carbon  High
# 96        Trigger Carbon 4  Mountain       Over Mountain    Carbon  High
# 94        Trigger Carbon 2  Mountain       Over Mountain    Carbon  High
# 0              Bad Habit 1  Mountain               Trail  Aluminum  High
# 23         F-Si Black Inc.  Mountain  Cross Country Race    Carbon  High
# 47   Scalpel-Si Black Inc.  Mountain  Cross Country Race    Carbon  High
#
#           X1
# 45  0.030823
# 34  0.028047
# 49  0.027905
# 39  0.026506
# 95  0.023688
# 96  0.023114
# 94  0.021636
# 0   0.021605
# 23  0.021231
# 47  0.020406

# %% [markdown]
# ### Extra credit
#
# #### Hierarchical clustering [link](https://www.analyticsvidhya.com/blog/2019/05/beginners-guide-hierarchical-clustering/ )
#     Q Compare the result to the use of k-means and note any differences.
#
#
# - From the dendrograms, the cluster equals to 4 seems to be the best cluster number.
# - Compred to the results with Kmeans, all cluster assignment results are the exactly **SAME** for both clustering methods. This is great which means the cluster number 4 is great and our assumption is great.

# %%
# The x-axis contains the samples and y-axis represents the distance between these samples. 
# The vertical line with maximum distance is the blue line and hence we can decide a threshold of 0.15 and cut the dendrogram:

plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(X, method='ward'))
plt.axhline(y=0.15, color='r', linestyle='--')

# %%
cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
cluster_map1 = pd.DataFrame()
cluster_map1['customer'] = X.index
cluster_map1['cluster'] = cluster.fit_predict(X)

for i in range(best_k):
    print("="*15 + "Cluster " + str(i) + " Agglomerative Clustering "+"="*15  )
    print(cluster_map1[cluster_map1["cluster"] == i]["customer"])
    print("*"*60)
    print("="*15 + "Cluster " + str(i) +" Kmeans Clustering "+ "="*15)
    print(cluster_map[cluster_map["cluster"] == i]["customer"])
    print()
# Out:
# ===============Cluster 0 Agglomerative Clustering ===============
# 1                  Ann Arbor Speed
# 2                  Austin Cruisers
# 8         Indianapolis Velocipedes
# 14            Miami Race Equipment
# 16              Nashville Cruisers
# 17         New Orleans Velocipedes
# 19    Oklahoma City Race Equipment
# 27          Seattle Race Equipment
# Name: customer, dtype: object
# ************************************************************
# ===============Cluster 0 Kmeans Clustering ===============
# 1                  Ann Arbor Speed
# 2                  Austin Cruisers
# 8         Indianapolis Velocipedes
# 14            Miami Race Equipment
# 16              Nashville Cruisers
# 17         New Orleans Velocipedes
# 19    Oklahoma City Race Equipment
# 27          Seattle Race Equipment
# Name: customer, dtype: object
#
# ===============Cluster 1 Agglomerative Clustering ===============
# 0         Albuquerque Cycles
# 5              Dallas Cycles
# 6           Denver Bike Shop
# 7             Detroit Cycles
# 10         Kansas City 29ers
# 12        Los Angeles Cycles
# 15     Minneapolis Bike Shop
# 18           New York Cycles
# 20    Philadelphia Bike Shop
# 21           Phoenix Bi-peds
# 23          Portland Bi-peds
# 24        Providence Bi-peds
# 25     San Antonio Bike Shop
# Name: customer, dtype: object
# ************************************************************
# ===============Cluster 1 Kmeans Clustering ===============
# 0         Albuquerque Cycles
# 5              Dallas Cycles
# 6           Denver Bike Shop
# 7             Detroit Cycles
# 10         Kansas City 29ers
# 12        Los Angeles Cycles
# 15     Minneapolis Bike Shop
# 18           New York Cycles
# 20    Philadelphia Bike Shop
# 21           Phoenix Bi-peds
# 23          Portland Bi-peds
# 24        Providence Bi-peds
# 25     San Antonio Bike Shop
# Name: customer, dtype: object
#
# ===============Cluster 2 Agglomerative Clustering ===============
# 9         Ithaca Mountain Climbers
# 22    Pittsburgh Mountain Machines
# 28                     Tampa 29ers
# Name: customer, dtype: object
# ************************************************************
# ===============Cluster 2 Kmeans Clustering ===============
# 3              Cincinnati Speed
# 4       Columbus Race Equipment
# 11             Las Vegas Cycles
# 13    Louisville Race Equipment
# 26       San Francisco Cruisers
# 29                Wichita Speed
# Name: customer, dtype: object
#
# ===============Cluster 3 Agglomerative Clustering ===============
# 3              Cincinnati Speed
# 4       Columbus Race Equipment
# 11             Las Vegas Cycles
# 13    Louisville Race Equipment
# 26       San Francisco Cruisers
# 29                Wichita Speed
# Name: customer, dtype: object
# ************************************************************
# ===============Cluster 3 Kmeans Clustering ===============
# 9         Ithaca Mountain Climbers
# 22    Pittsburgh Mountain Machines
# 28                     Tampa 29ers
# Name: customer, dtype: object

# %%
import sklearn
from sklearn import datasets

# %%
! mv /Users/yaohanjiang/Desktop/Shuati-Notebook/AWS_ML/linuxacademy /Users/yaohanjiang/Desktop/Shuati-Notebook/AWS_ML/
# Out:
# mv: /Users/yaohanjiang/Desktop/Shuati-Notebook/AWS_ML/linuxacademy and /Users/yaohanjiang/Desktop/Shuati-Notebook/AWS_ML/linuxacademy are identical

# %%
digits = datasets.load_digits()
d = zip(digits.data, digits.target)
d = list(d)

# %%
import matplotlib.pyplot as plt
print("target: " + str(d[0][1]))
plt.imshow(d[0][0].reshape(8,8))
plt.show()

# %%
num_rows = 5
num_cols = 2

num_images = num_rows * num_cols
plt.figure(figsize= (15,6))
y = d

for i in range(num_images):
    plt.subplot(num_cols, num_rows,i+1)
    plt.imshow(y[i][0].reshape(8,8))
    plt.title(y[i][1])
plt.show()

# %%
from sklearn.utils import shuffle

# %%
shuffled_d = shuffle(d)

# %%
plt.figure(figsize= (15,6))
y = shuffled_d

for i in range(num_images):
    plt.subplot(num_cols, num_rows,i+1)
    plt.imshow(y[i][0].reshape(8,8))
    plt.title(y[i][1])
plt.show()
